# %% [markdown]
# <a href="https://colab.research.google.com/github/Riccardolotorto/Python/blob/main/LOTORTO_RICCARDO_EsercizioPandasTeams.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. caricare il file

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
squadre = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Teams.xlsx")

# %%
squadre
# Out:
#               Name      Discipline                         NOC  Event
# 0          Belgium  3x3 Basketball                     Belgium    Men
# 1            China  3x3 Basketball  People's Republic of China    Men
# 2            China  3x3 Basketball  People's Republic of China  Women
# 3           France  3x3 Basketball                      France  Women
# 4            Italy  3x3 Basketball                       Italy  Women
# ..             ...             ...                         ...    ...
# 738   South Africa      Water Polo                South Africa  Women
# 739          Spain      Water Polo                       Spain    Men
# 740          Spain      Water Polo                       Spain  Women
# 741  United States      Water Polo    United States of America    Men
# 742  United States      Water Polo    United States of America  Women
#
# [743 rows x 4 columns]

# %% [markdown]
# 2. visualizzare le discipline a cui l'Italia ha partecipato

# %%
squadre[squadre["NOC"] == "Italy"][["Discipline"]]
# Out:
#               Discipline
# 4         3x3 Basketball
# 41               Archery
# 42               Archery
# 80   Artistic Gymnastics
# 109    Artistic Swimming
# 110    Artistic Swimming
# 164            Athletics
# 165            Athletics
# 166            Athletics
# 167            Athletics
# 168            Athletics
# 208    Baseball/Softball
# 227           Basketball
# 259     Beach Volleyball
# 260     Beach Volleyball
# 261     Beach Volleyball
# 322        Cycling Track
# 323        Cycling Track
# 324        Cycling Track
# 325        Cycling Track
# 373              Fencing
# 374              Fencing
# 375              Fencing
# 376              Fencing
# 377              Fencing
# 378              Fencing
# 488  Rhythmic Gymnastics
# 581             Swimming
# 582             Swimming
# 583             Swimming
# 584             Swimming
# 585             Swimming
# 586             Swimming
# 687            Triathlon
# 706           Volleyball
# 707           Volleyball
# ...

# %% [markdown]
# 3. visualizzare il numero di discipline a cui hanno partecipato gli Stati Uniti

# %%
squadre[squadre["NOC"] == "United States of America"]["Discipline"].count()
# Out:
# 47

# %% [markdown]
# 4.  visualizzare il numero di squadre di basket femminile

# %%
squadre[(squadre["Discipline"] == "Basketball") & (squadre["Event"] == "Women")]["Event"].count()
# Out:
# 12

# %% [markdown]
# 5.  visualizzare le discipline a cui hanno partecipato la Gran Bretagna e la Francia

# %%
squadre[(squadre["NOC"] == "France") | (squadre["NOC"] == "Great Britain")][["Discipline"]]
# Out:
#          Discipline
# 3    3x3 Basketball
# 30          Archery
# 31          Archery
# 34          Archery
# 35          Archery
# ..              ...
# 651    Table Tennis
# 652    Table Tennis
# 683       Triathlon
# 685       Triathlon
# 704      Volleyball
#
# [61 rows x 1 columns]

# %% [markdown]
# 6. controllare se le discipline a cui ha partecipato l'Italia sono di più o di meno di quelle a cui ha partecipato la Spagna

# %%
print("le discipline a cui ha partecipato l'Italia sono di più di quelle della Spagna" if squadre[squadre["NOC"] == "Italy"]["Discipline"].count() > squadre[squadre["NOC"] == "Spain"]["Discipline"].count() else "le discipline a cui ha partecipato la Spagna sono di più di quelle dell'Italia")
# Out:
# le discipline a cui ha partecipato l'Italia sono di più di quelle della Spagna

# %% [markdown]
# 7. visualizzare tutti le discipline in cui compare la parola 'water'

# %%
squadre[squadre["Discipline"].str.contains("Water")][["Discipline"]]
# Out:
#      Discipline
# 721  Water Polo
# 722  Water Polo
# 723  Water Polo
# 724  Water Polo
# 725  Water Polo
# 726  Water Polo
# 727  Water Polo
# 728  Water Polo
# 729  Water Polo
# 730  Water Polo
# 731  Water Polo
# 732  Water Polo
# 733  Water Polo
# 734  Water Polo
# 735  Water Polo
# 736  Water Polo
# 737  Water Polo
# 738  Water Polo
# 739  Water Polo
# 740  Water Polo
# 741  Water Polo
# 742  Water Polo

# %% [markdown]
# 8. visualizzare tutti i dati ordinandoli in ordine alfabetico sul nome della nazione

# %%
squadre.sort_values(by="NOC", ignore_index = True)
# Out:
#                  Name           Discipline                       NOC  \
# 0              Angola             Handball                    Angola
# 1           Argentina         Rugby Sevens                 Argentina
# 2           Argentina             Football                 Argentina
# 3      Gallay/Pereyra     Beach Volleyball                 Argentina
# 4    Azaad/Capogrosso     Beach Volleyball                 Argentina
# ..                ...                  ...                       ...
# 738     United States           Water Polo  United States of America
# 739        Uzbekistan  Rhythmic Gymnastics                Uzbekistan
# 740         Venezuela           Volleyball                 Venezuela
# 741           Vietnam              Archery                   Vietnam
# 742            Zambia             Football                    Zambia
#
#                 Event
# 0               Women
# 1                 Men
# 2                 Men
# 3               Women
# ...

# %% [markdown]
# 9. eliminare tutti i record relativi alla Cina

# %%
squadre.drop(squadre[squadre["NOC"] == "People's Republic of China"].index, inplace = True)
