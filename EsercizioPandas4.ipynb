# %% [markdown]
# <a href="https://colab.research.google.com/github/Riccardolotorto/Python/blob/main/EsercizioPandas4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. caricare il file excel

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
passeggeri = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/LOTORTO RICCARDO - titanic.csv', delimiter = ";")
passeggeri
# Out:
# Mounted at /content/drive
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund; Mr. Owen Harris    male  22.0      1
# 1    Cumings; Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen; Miss. Laina  female  26.0      0
# 3         Futrelle; Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen; Mr. William Henry    male  35.0      0
# ...

# %% [markdown]
# 2. visualizzare il numero di passeggeri

# %%
passeggeri["PassengerId"].count()
# Out:
# 891

# %% [markdown]
# 3. visualizzare il numero di passeggeri sopravvissuti

# %%
passeggeri[passeggeri["Survived"] == 1]["Survived"].count()
# Out:
# 342

# %% [markdown]
# 4. visualizzare il numero di passeggeri maschi sopravvissuti

# %%
passeggeri[(passeggeri["Sex"] == "male") & (passeggeri["Survived"] == 1)]["Survived"].count()
# Out:
# 109

# %% [markdown]
# 5. visualizzare la percentuale di passeggeri maschi sopravvissuti

# %%
print((passeggeri[(passeggeri["Sex"] == "male") & (passeggeri["Survived"] == 1)]["Survived"].count() / passeggeri[passeggeri["Survived"] == 1]["Survived"].count()) * 100)
# Out:
# 31.871345029239766

# %% [markdown]
# 6.  in numeri assoluti, sono sopravvissuti più maschi o più femmine?

# %%
print("sono sopravvissuti più maschi" if passeggeri[(passeggeri["Sex"] == "male") & (passeggeri["Survived"] == 1)]["Survived"].count() > passeggeri[(passeggeri["Sex"] == "famale") & (passeggeri["Survived"] == 1)]["Survived"].count() else "sono sopravvisute più femmine")
# Out:
# sono sopravvissuti più maschi

# %% [markdown]
# 7.  in percentuale, sono sopravvissuti più maschi o più femmine?

# %%
print("sono sopravvisuti più maschi" if (passeggeri[(passeggeri["Sex"] == "male") & (passeggeri["Survived"] == 1)]["Survived"].count() / passeggeri[passeggeri["Survived"] == 1]["Survived"].count()) * 100 > (passeggeri[(passeggeri["Sex"] == "female") & (passeggeri["Survived"] == 1)]["Survived"].count() / passeggeri[passeggeri["Survived"] == 1]["Survived"].count()) * 100 else "sono sopravvissute più femmine")
# Out:
# sono sopravvissute più femmine

# %% [markdown]
# 8. visualizzare i passeggeri che si chiamavano William

# %%
passeggeri[passeggeri["Name"].str.contains("William")]
# Out:
#      PassengerId  Survived  Pclass  \
# 4              5         0       3
# 12            13         0       3
# 17            18         1       2
# 23            24         1       1
# 31            32         1       1
# ..           ...       ...     ...
# 802          803         1       1
# 810          811         0       3
# 864          865         0       2
# 880          881         1       2
# 885          886         0       3
#
#                                                Name     Sex   Age  SibSp  \
# 4                          Allen; Mr. William Henry    male  35.0      0
# 12                   Saundercock; Mr. William Henry    male  20.0      0
# 17                     Williams; Mr. Charles Eugene    male   NaN      0
# 23                     Sloper; Mr. William Thompson    male  28.0      0
# 31   Spencer; Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# ..                                              ...     ...   ...    ...
# ...

# %% [markdown]
# 9. visualizzare i passeggeri che NON si chiamavano William

# %%
passeggeri[passeggeri["Name"].str.contains("William") == False]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund; Mr. Owen Harris    male  22.0      1
# 1    Cumings; Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen; Miss. Laina  female  26.0      0
# 3         Futrelle; Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 5                                     Moran; Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# 10.  visualizzare il numero di passeggeri con un'età compresa tra 20 e 30 anni

# %%
passeggeri[(passeggeri["Age"] >= 20) & (passeggeri["Age"] <= 30)]["Age"].count()
# Out:
# 245

# %% [markdown]
# 11. visualizzare l'età media dei sopravvissuti

# %%
passeggeri[passeggeri["Survived"] == 1]["Age"].mean()
# Out:
# 28.343689655172415

# %% [markdown]
# 12. visualizzare la differenza tra la tariffa media pagata dai passeggeri di prima classe e quella dei passeggeri di terza classe

# %%
print(passeggeri[passeggeri["Pclass"] == 1]["Fare"].mean())
print(passeggeri[passeggeri["Pclass"] == 3]["Fare"].mean())
print(passeggeri[passeggeri["Pclass"] == 1]["Fare"].mean() - passeggeri[passeggeri["Pclass"] == 3]["Fare"].mean())
# Out:
# 84.1546875
# 13.675550101832993
# 70.479137398167

# %% [markdown]
# 13. i nomi dei passeggeri di cui non si sa in che cabina si trovavano

# %%
passeggeri[passeggeri["Cabin"].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund; Mr. Owen Harris
# 2              3         1       3                    Heikkinen; Miss. Laina
# 4              5         0       3                  Allen; Mr. William Henry
# 5              6         0       3                          Moran; Mr. James
# 7              8         0       3            Palsson; Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall; Mr. Henry Jr
# 885          886         0       3      Rice; Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila; Rev. Juozas
# 888          889         0       3  Johnston; Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley; Mr. Patrick
#
# ...
