# %% [markdown]
# <a href="https://colab.research.google.com/github/Riccardolotorto/Python/blob/main/LOTORTO_RICCARDO_EsercizioPandasMedaglie1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  1. caricare i dati del file in un dataframe Pandas

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
medaglie = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Medals.xlsx")
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
medaglie
# Out:
#     Rank                    Team/NOC  Gold  Silver  Bronze  Total  \
# 0      1    United States of America    39      41      33    113
# 1      2  People's Republic of China    38      32      18     88
# 2      3                       Japan    27      14      17     58
# 3      4               Great Britain    22      21      22     65
# 4      5                         ROC    20      28      23     71
# ..   ...                         ...   ...     ...     ...    ...
# 88    86                       Ghana     0       0       1      1
# 89    86                     Grenada     0       0       1      1
# 90    86                      Kuwait     0       0       1      1
# 91    86         Republic of Moldova     0       0       1      1
# 92    86        Syrian Arab Republic     0       0       1      1
#
#     Rank by Total
# 0               1
# 1               2
# 2               5
# 3               4
# 4               3
# ..            ...
# 88             77
# ...

# %% [markdown]
# 2. visualizzare il totale delle medaglie delle prime 10 nazioni

# %%
medaglie.head(10)[["Total"]]
# Out:
#    Total
# 0    113
# 1     88
# 2     58
# 3     65
# 4     71
# 5     46
# 6     36
# 7     33
# 8     37
# 9     40

# %% [markdown]
# 3. visualizzare la nazione (o le nazioni) che ha vinto, in totale, meno medaglie

# %%
medaglie[medaglie["Total"] == medaglie["Total"].min()][["Team/NOC"]]
# Out:
#                 Team/NOC
# 62               Bermuda
# 63               Morocco
# 64           Puerto Rico
# 76               Bahrain
# 77          Saudi Arabia
# 78             Lithuania
# 79       North Macedonia
# 80               Namibia
# 81          Turkmenistan
# 85              Botswana
# 86          Burkina Faso
# 87         Côte d'Ivoire
# 88                 Ghana
# 89               Grenada
# 90                Kuwait
# 91   Republic of Moldova
# 92  Syrian Arab Republic

# %% [markdown]
# 4.  visualizzare le nazioni che hanno vinto più medaglie di bronzo rispetto alle medaglie d'argento

# %%
medaglie[medaglie["Bronze"] > medaglie["Silver"]][["Team/NOC"]]
# Out:
#                 Team/NOC
# 2                  Japan
# 3          Great Britain
# 5              Australia
# 6            Netherlands
# 8                Germany
# 9                  Italy
# 10                Canada
# 11                Brazil
# 12           New Zealand
# 13                  Cuba
# 15     Republic of Korea
# 20               Jamaica
# 23           Switzerland
# 27                Serbia
# 28               Belgium
# 29              Bulgaria
# 31            Uzbekistan
# 33        Chinese Taipei
# 34                Turkey
# 38               Ireland
# 39                Israel
# 40                 Qatar
# 43               Ukraine
# 47                 India
# 48      Hong Kong, China
# 52               Austria
# 53                 Egypt
# 54             Indonesia
# 55              Ethiopia
# 56              Portugal
# 58               Estonia
# 59                  Fiji
# 60                Latvia
# 61              Thailand
# 66            Azerbaijan
# 70              Mongolia
# ...

# %% [markdown]
# 5. visualizzare il numero di nazioni che non hanno vinto medaglie d'oro

# %%
medaglie[medaglie["Gold"] == 0]["Gold"].count()
# Out:
# 28

# %% [markdown]
# 6. visualizzare il numero totale di medaglie d'oro e d'argento

# %%
print(medaglie["Gold"].sum())
print(medaglie["Silver"].sum())
# Out:
# 340
# 338

# %% [markdown]
# 7. visualizzare la nazione che ha vinto più medaglie di bronzo

# %%
medaglie[medaglie["Bronze"] == medaglie["Bronze"].max()][["Team/NOC"]]
# Out:
#                    Team/NOC
# 0  United States of America

# %% [markdown]
# 8. visualizzare le nazioni che non hanno vinto medaglie d'argento

# %%
medaglie[medaglie["Silver"] == 0][["Team/NOC"]]
# Out:
#                 Team/NOC
# 31            Uzbekistan
# 38               Ireland
# 39                Israel
# 40                 Qatar
# 41               Bahamas
# 42                Kosovo
# 58               Estonia
# 59                  Fiji
# 60                Latvia
# 61              Thailand
# 62               Bermuda
# 63               Morocco
# 64           Puerto Rico
# 82            Kazakhstan
# 83                Mexico
# 84               Finland
# 85              Botswana
# 86          Burkina Faso
# 87         Côte d'Ivoire
# 88                 Ghana
# 89               Grenada
# 90                Kuwait
# 91   Republic of Moldova
# 92  Syrian Arab Republic

# %% [markdown]
# 9.  visualizzare le nazioni che hanno vinto un numero di medaglie d'argento superiore alla media

# %%
medaglie[medaglie["Silver"] > medaglie["Silver"].mean()][["Team/NOC"]]
# Out:
#                       Team/NOC
# 0     United States of America
# 1   People's Republic of China
# 2                        Japan
# 3                Great Britain
# 4                          ROC
# 5                    Australia
# 6                  Netherlands
# 7                       France
# 8                      Germany
# 9                        Italy
# 10                      Canada
# 11                      Brazil
# 12                 New Zealand
# 14                     Hungary
# 15           Republic of Korea
# 16                      Poland
# 17              Czech Republic
# 18                       Kenya
# 21                       Spain
# 22                      Sweden
# 23                 Switzerland
# 24                     Denmark
# 32                     Georgia
# 33              Chinese Taipei
# 43                     Ukraine
# 65                    Colombia
